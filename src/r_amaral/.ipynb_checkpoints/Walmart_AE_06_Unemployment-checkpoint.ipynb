# %%
df = read.csv("./Walmart_Sales_Updated.csv")

# %%
#Conferir se já não foi alterado e converter coluna 'Date pata formato Date
if ( class(df$Date) != "Date" ) {
  df$Date = as.Date(df$Date, format = "%Y-%m-%d")
}

# %%
head(df)
# Out:
#   X Store Date       Weekly_Sales Holiday_Flag Temperature Fuel_Price CPI
# 1 1 1     2010-02-05 1643691      0            42.31       2.572      211.0964
# 2 2 1     2010-02-12 1641957      1            38.51       2.548      211.2422
# 3 3 1     2010-02-19 1611968      0            39.93       2.514      211.2891
# 4 4 1     2010-02-26 1409728      0            46.63       2.561      211.3196
# 5 5 1     2010-03-05 1554807      0            46.50       2.625      211.3501
# 6 6 1     2010-03-12 1439542      0            57.79       2.667      211.3806
#   Unemployment Weekly_CPI
# 1 8.106                NA
# 2 8.106        0.06907348
# 3 8.106        0.02223661
# 4 8.106        0.01443520
# 5 8.106        0.01443311
# 6 8.106        0.01443103

# %% [markdown]
# Estudando o efeito do preço do desemprego

# %%
nstore = 22
if (nstore > 0){
    dfplot = df[(df$Store == nstore),]
} else {
    dfplot = df
}


plot(dfplot$Unemployment,dfplot$Weekly_Sales/1000000,
    ylab = 'Weekly Sales MM',
    xlab = 'Unemployment',
    main = paste( 'Com Outliers - Loja: ', nstore))
lm_model = lm(dfplot$Weekly_Sales/1000000 ~ dfplot$Unemployment)
abline(lm_model, col="red")

r_squared = summary(lm_model)$r.squared
legend("bottomright", legend=paste("r2 =", round(r_squared, 5)), 
       lty=1, col="red", text.col="red")
# Out:
# Plot with title "Com Outliers - Loja:  22"

# %%
# Calculate Q1, Q3, and IQR
if (nstore > 0){
    Q1 <- quantile(df[df$Store == nstore,]$Weekly_Sales, 0.25)
    Q3 <- quantile(df[df$Store == nstore,]$Weekly_Sales, 0.75)
    } else {
    Q1 <- quantile(df$Weekly_Sales, 0.25)
    Q3 <- quantile(df$Weekly_Sales, 0.75) 
    }

IQR <- Q3 - Q1

# Define outlier bounds
lower_bound <- Q1 - 1.5 * IQR
upper_bound <- Q3 + 1.5 * IQR

if (nstore > 0){
   dfplot = df[(df$Store == nstore) & (df$Weekly_Sales > lower_bound) & (df$Weekly_Sales < upper_bound),]
} else {
    dfplot = dfplot = df[(df$Weekly_Sales > lower_bound) & (df$Weekly_Sales < upper_bound),]
}



plot(dfplot$Unemployment,dfplot$Weekly_Sales/1000000,
    ylab = 'Weekly Sales MM',
    xlab = 'Unemployment',
    main = paste( 'Sem Outliers - Loja: ', nstore))
lm_model = lm(dfplot$Weekly_Sales/1000000 ~dfplot$Unemployment)
abline(lm_model, col="red")
r_squared = summary(lm_model)$r.squared
legend("bottomright", legend=paste("r2 =", round(r_squared, 5)), 
       lty=1, col="red", text.col="red")
# Out:
# Plot with title "Sem Outliers - Loja:  22"

# %%
dfplot = df[(df$Store == nstore),]

minU = min(dfplot[dfplot$Store == nstore,]$Unemployment/4)
minS =  min(dfplot[dfplot$Store == nstore,]$Weekly_Sales/1000000)
minD = minU - minS

plot(dfplot$Date,dfplot$Weekly_Sales/1000000,
    type='l',
    ylab = 'Weekly Sales MM',
    xlab = 'Weeks',
    main = paste( 'Vendas e Desemprego - Loja: ', nstore))
lines(dfplot$Date,(dfplot$Unemployment/4)-minD,
      col = "red")
legend("topright", legend="Unemployment", lty=1, col="red", text.col="black")
# Out:
# Plot with title "Vendas e Desemprego - Loja:  22"

# %% [markdown]
# A correlação direta entre a desemprego e as vendas é fraca.
# Agora será verificada am distribuição de vendas por quartis de desemprego.

# %%
Q0_Unimp = min(dfplot[dfplot$Store == nstore,]$Unemployment)
Q1_Unimp = quantile(dfplot[dfplot$Store == nstore,]$Unemployment, 0.25)
Q2_Unimp = quantile(dfplot[dfplot$Store == nstore,]$Unemployment, 0.50)
Q3_Unimp = quantile(dfplot[dfplot$Store == nstore,]$Unemployment, 0.75)
Q4_Unimp = max(dfplot[dfplot$Store == nstore,]$Unemployment)
dfplot$Unimp_Quantile = ''

label_1 = paste("A: ",round(Q0_Unimp, 2)," - ",round(Q1_Unimp, 2))
label_2 = paste("B: ",round(Q1_Unimp, 2)," - ",round(Q2_Unimp, 2))
label_3 = paste("C: ",round(Q2_Unimp, 2)," - ",round(Q3_Unimp, 2))
label_4 = paste("D: ",round(Q3_Unimp, 2)," - ",round(Q4_Unimp, 2))

dfplot$Unimp_Quantile = ifelse(dfplot$Unemployment <= Q1_Unimp,label_1, dfplot$Unimp_Quantile)
dfplot$Unimp_Quantile = ifelse(dfplot$Unemployment > Q1_Unimp & dfplot$Unemployment <= Q2_Unimp ,label_2, dfplot$Unimp_Quantile)
dfplot$Unimp_Quantile = ifelse(dfplot$Unemployment > Q2_Unimp & dfplot$Unemployment <= Q3_Unimp ,label_3, dfplot$Unimp_Quantile)
dfplot$Unimp_Quantile = ifelse(dfplot$Unemployment > Q3_Unimp,label_4, dfplot$Unimp_Quantile)

bp = boxplot(Weekly_Sales/1000000 ~ Unimp_Quantile, 
        data = dfplot,
        ylab = 'Weekly Sales (MM)',
        xlab = 'Unemployment Rate',
        main = paste( 'Vendas e Desemprego - Loja: ', nstore)
       )
# Out:
# Plot with title "Vendas e Desemprego - Loja:  22"

# %% [markdown]
# Resultado curioso, vendas parecem aumentar não conversar com desemprego.

# %%
print(bp$stats)
# Out:
#           [,1]      [,2]      [,3]      [,4]
# [1,] 0.8554376 0.8998348 0.8997615 0.7742623
# [2,] 0.9708233 0.9576339 0.9735853 0.9112454
# [3,] 1.0040398 0.9875061 1.0097637 0.9684817
# [4,] 1.0778209 1.0219196 1.0611965 1.0257663
# [5,] 1.1974897 1.0977861 1.1773410 1.0436986

# %%
sums <- aggregate(Weekly_Sales ~ Unimp_Quantile, dfplot, sum)

# Create barplot
barplot(sums$Weekly_Sales/1000000, 
        names.arg = sums$Unimp_Quantile,
        main = "Vendas e Desemprego",
        xlab = "Unenployment",
        ylab = "Weekly Sales (MM)"
        )
# Out:
# Plot with title "Vendas e Desemprego"
